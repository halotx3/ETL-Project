# %%
#START
import pandas as pd
from sqlalchemy import create_engine

# %%
## Importing the Netflix CSV and converting it into a dataframe to clean and edit ##
netflix_csv = "./Resources/netflix_titles.csv"
netflix_df = pd.read_csv(netflix_csv)
netflix_df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
# 2                             United States  September 8, 2018          2013
# 3                             United States  September 8, 2018          2016
# 4                             United States  September 8, 2017          2017
#
#      rating  duration                           listed_in  \
# 0     TV-PG    90 min  Children & Family Movies, Comedies
# 1     TV-MA    94 min                     Stand-Up Comedy
# 2  TV-Y7-FV  1 Season                            Kids' TV
# 3     TV-Y7  1 Season                            Kids' TV
# 4     TV-14    99 min                            Comedies
#
#                                          description
# 0  Before planning an awesome wedding for his gra...
# 1  Jandino Asporaat riffs on the challenges of ra...
# 2  With the help of three human allies, the Autob...
# 3  When a prison ship crash unleashes hundreds of...
# 4  When nerdy high schooler Dani finally attracts...

# %%
## Importing the Movie Streaming CSV and converting it into a dataframe to clean and edit ##
movies_csv = "./Resources/MoviesOnStreaming.csv"
movies_df = pd.read_csv(movies_csv)
movies_df.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age  IMDb  \
# 0           0   1                       Inception  2010  13+   8.8
# 1           1   2                      The Matrix  1999  18+   8.7
# 2           2   3          Avengers: Infinity War  2018  13+   8.5
# 3           3   4              Back to the Future  1985   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+   8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime
# 0  United States,United Kingdom  English,Japanese,French    148.0
# 1                 United States                  English    136.0
# 2                 United States                  English    149.0
# 3                 United States                  English    116.0
# 4      Italy,Spain,West Germany                  Italian    161.0

# %%
netflix_col = ["show_id", "title", "rating", "duration"]
netflix_fil = netflix_df.loc[netflix_df["type"] == "Movie"]
netflix_fix = netflix_fil.reindex(columns=netflix_col)
netflix_fix.dropna()
netflix_fix.head()
# Out:
#     show_id                                    title rating duration
# 0  81145628  Norm of the North: King Sized Adventure  TV-PG   90 min
# 1  80117401               Jandino: Whatever it Takes  TV-MA   94 min
# 4  80125979                             #realityhigh  TV-14   99 min
# 6  70304989                                 Automata      R  110 min
# 7  80164077       Fabrizio Copano: Solo pienso en mi  TV-MA   60 min

# %%
movies_fixed = movies_df.drop(columns=['Hulu','Prime Video', 'Disney+','Type','Directors','Genres','Country', 'Language','Runtime'])
movies_fixed = movies_fixed.rename(columns={"Rotten Tomatoes": "rotten_tomatoes",
                                           "ID": "id",
                                           "Title": "title",
                                           "Year": "year",
                                           "Age": "age",
                                           "IMDb": "imdb",
                                           "Netflix": "netflix"})

movies_fixed.set_index("id")
movies_fixed = movies_fixed.drop(movies_fixed.filter(regex="Unname"),axis=1)

movies_fixed.head()
# Out:
#    id                           title  year  age  imdb rotten_tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#    netflix
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
#Connection to the database
connection_string = "postgres:postgres@localhost:5432/movies_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['netflix_data', 'streaming_data']

# %%
#load data into netflex data table
netflix_fix.to_sql(name='netflix_data', con=engine, if_exists='append', index=False)

# %%
#load data into streaming data table
movies_fixed.to_sql(name='streaming_data', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~/opt/anaconda3/envs/ds/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1227                     self.dialect.do_executemany(
# -> 1228                         cursor, statement, parameters, context
#    1229                     )
#
# ~/opt/anaconda3/envs/ds/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     856         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 857             cursor.executemany(statement, parameters)
#     858             return
#
# UndefinedColumn: column "id" of relation "streaming_data" does not exist
# LINE 1: INSERT INTO streaming_data (id, title, year, age, imdb, rott...
#                                     ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-55-af5cdc6e6910> in <module>
#       1 #load data into streaming data table
# ----> 2 movies_fixed.to_sql(name='streaming_data', con=engine, if_exists='append', index=False)
#
# ~/opt/anaconda3/envs/ds/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~/opt/anaconda3/envs/ds/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~/opt/anaconda3/envs/ds/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~/opt/anaconda3/envs/ds/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~/opt/anaconda3/envs/ds/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/opt/anaconda3/envs/ds/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     982             )
#     983         else:
# --> 984             return meth(self, multiparams, params)
#     985
#     986     def _execute_function(self, func, multiparams, params):
#
# ~/opt/anaconda3/envs/ds/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     291     def _execute_on_connection(self, connection, multiparams, params):
#     292         if self.supports_execution:
# --> 293             return connection._execute_clauseelement(self, multiparams, params)
#     294         else:
#     295             raise exc.ObjectNotExecutableError(self)
#
# ~/opt/anaconda3/envs/ds/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1101             distilled_params,
#    1102             compiled_sql,
# -> 1103             distilled_params,
#    1104         )
#    1105         if self._has_events or self.engine._has_events:
#
# ~/opt/anaconda3/envs/ds/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1286         except BaseException as e:
#    1287             self._handle_dbapi_exception(
# -> 1288                 e, statement, parameters, cursor, context
#    1289             )
#    1290
#
# ~/opt/anaconda3/envs/ds/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1480             elif should_wrap:
#    1481                 util.raise_(
# -> 1482                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1483                 )
#    1484             else:
#
# ~/opt/anaconda3/envs/ds/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~/opt/anaconda3/envs/ds/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1226                 if not evt_handled:
#    1227                     self.dialect.do_executemany(
# -> 1228                         cursor, statement, parameters, context
#    1229                     )
#    1230             elif not parameters and context.no_parameters:
#
# ~/opt/anaconda3/envs/ds/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     855     def do_executemany(self, cursor, statement, parameters, context=None):
#     856         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 857             cursor.executemany(statement, parameters)
#     858             return
#     859
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "id" of relation "streaming_data" does not exist
# LINE 1: INSERT INTO streaming_data (id, title, year, age, imdb, rott...
#                                     ^
#
# [SQL: INSERT INTO streaming_data (id, title, year, age, imdb, rotten_tomatoes, netflix) VALUES (%(id)s, %(title)s, %(year)s, %(age)s, %(imdb)s, %(rotten_tomatoes)s, %(netflix)s)]
# [parameters: ({'id': 1, 'title': 'Inception', 'year': 2010, 'age': '13+', 'imdb': 8.8, 'rotten_tomatoes': '87%', 'netflix': 1}, {'id': 2, 'title': 'The Matrix', 'year': 1999, 'age': '18+', 'imdb': 8.7, 'rotten_tomatoes': '87%', 'netflix': 1}, {'id': 3, 'title': 'Avengers: Infinity War', 'year': 2018, 'age': '13+', 'imdb': 8.5, 'rotten_tomatoes': '84%', 'netflix': 1}, {'id': 4, 'title': 'Back to the Future', 'year': 1985, 'age': '7+', 'imdb': 8.5, 'rotten_tomatoes': '96%', 'netflix': 1}, {'id': 5, 'title': 'The Good, the Bad and the Ugly', 'year': 1966, 'age': '18+', 'imdb': 8.8, 'rotten_tomatoes': '97%', 'netflix': 1}, {'id': 6, 'title': 'Spider-Man: Into the Spider-Verse', 'year': 2018, 'age': '7+', 'imdb': 8.4, 'rotten_tomatoes': '97%', 'netflix': 1}, {'id': 7, 'title': 'The Pianist', 'year': 2002, 'age': '18+', 'imdb': 8.5, 'rotten_tomatoes': '95%', 'netflix': 1}, {'id': 8, 'title': 'Django Unchained', 'year': 2012, 'age': '18+', 'imdb': 8.4, 'rotten_tomatoes': '87%', 'netflix': 1}  ... displaying 10 of 16744 total bound parameter sets ...  {'id': 16743, 'title': 'Man Among Cheetahs', 'year': 2017, 'age': None, 'imdb': 6.6, 'rotten_tomatoes': None, 'netflix': 0}, {'id': 16744, 'title': 'In Beaver Valley', 'year': 1950, 'age': None, 'imdb': None, 'rotten_tomatoes': None, 'netflix': 0})]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
#Test pulling query from Netfix database
pd.read_sql_query('select * from netflix_data', con=engine).head()

# %%
#Test pulling query from Steaming database
pd.read_sql_query('select * from streaming_data', con=engine).head()
